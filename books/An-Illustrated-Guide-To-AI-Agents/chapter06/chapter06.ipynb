# %% [markdown]
# <h1>Chapter 6 - Planning</h1>
# <i>Autonomy for your `TinyAgent` through Native Tool Calling and Reasoning</i>
#
#
# <a href="https://www.amazon.com/Illustrated-Guide-AI-Agents-Concepts/dp/B0GTYL2QSJ"><img src="https://img.shields.io/badge/Buy%20the%20Book!-grey?logo=amazon"></a>
# <a href="https://www.oreilly.com/library/view/an-illustrated-guide/9798341662681/"><img src="https://img.shields.io/badge/O'Reilly-white.svg?logo=..."></a>
# <a href="https://github.com/HandsOnLLM/An-Illustrated-Guide-To-AI-Agents"><img src="https://img.shields.io/badge/GitHub%20Repository-black?logo=github"></a>
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HandsOnLLM/An-Illustrated-Guide-To-AI-Agents/blob/main/chapter06/chapter06.ipynb)
#
#
# ---
#
# This notebook is for Chapter 6 of [An Illustrated Guide to AI Agents](https://www.amazon.com/Illustrated-Guide-AI-Agents-Concepts/dp/B0GTYL2QSJ) by [Maarten Grootendorst](https://www.linkedin.com/in/mgrootendorst/) and [Jay Alammar](https://www.linkedin.com/in/jalammar).
#
# ---
#
# <a href="https://www.amazon.com/Illustrated-Guide-AI-Agents-Concepts/dp/B0GTYL2QSJ">
# <img src="https://learning.oreilly.com/covers/urn:orm:book:9798341662681/400w/" width="350"/></a>

# %% [markdown]
# ### **[OPTIONAL]** - Installing Packages on Google Colab <img src="https://upload.wikimedia.org/wikipedia/commons/d/d0/Google_Colaboratory_SVG_Logo.svg" width=100>
#
# If you are viewing this notebook on Google Colab (or any other cloud vendor), you need to **uncomment and run** one of the following codeblock to install the dependencies for this chapter. If you want to use a cloud provider, you only need to run the following code block:

# %%
# %%capture
# !pip install illustrated-agents

# %% [markdown]
# ---
#
# 💡 **NOTE**: If you want to use the GPU with `ollama`, then you will have to select a GPU first. In Google Colab, go to
# **Runtime > Change runtime type > Hardware accelerator > GPU > GPU type > T4**.
#
# Then, **uncomment** and run this codeblock:
#
# ---

# %%
# !apt-get install -y zstd > /dev/null 2>&1 && curl -fsSL https://ollama.com/install.sh | sh
# !nohup ollama serve > /dev/null 2>&1 & sleep 3 && ollama pull gemma4:e4b &

# %% [markdown]
# <hr style="height: 5px; border: none; border-radius: 5px; background: linear-gradient(to right, #000000, #7D7D7D);" />

# %% [markdown]
# ## 1 - Choosing Your LLM - `Gemma 3`
#
# At the beginning of every chapter, we start by choosing the LLM that we want to use. In this notebook, we will explore how to enable autonomous behavior for LLMs that do not have native tool calling and reasoning behavior. As such, the model that we will be using throughout this chapter is Gemma 3, a model that does not have native tool calling capabilities.

# %%
from illustrated_agents.chapters.ch2 import LLM

# Gemma 3 12B (no native thinking or tool calling)
llm = LLM(model="gemma3:12b")

# %% [markdown]
# If you want to use another LLM, here are a couple of options (both locally and on the cloud) that you can try:

# %%
# # llama.cpp
# llm = LLM(model="gemma-3-12B-it-Q4_K_M", base_url="http://127.0.0.1:8080")

# # LM Studio
# llm = LLM(model="gemma-3-12b-it", base_url="http://127.0.0.1:1234/v1")

# # OpenRouter
# import os
# llm = LLM(model="google/gemma-3-12b-it", base_url="https://openrouter.ai/api/v1", api_key=os.environ["OPENROUTER_API_KEY"])

# %% [markdown]
# ## 2 - Adding **`Autonomy`**
#
# In the previous chapter, we added the `Tools` module to your `TinyAgent`. In this chapter, we will cover how to give it more autonomy:
#
# ![../images/ch6.png](../images/ch6.png)

# %% [markdown]
# Throughout this notebook we will implement a module that allows for action sequencing, namely Reason and Act (ReAct).

# %% [markdown]
# ## 3 - Reason and Act (ReAct)

# %% [markdown]
# Autonomy, as covered in the book, is typically achieved through some method of task decomposition or planning. We are going to use the ReAct framework to give this autonomy to your `TinyAgent`. To do so, we are going to implement loops of:
#
# * `THOUGHT` - A reasoning step about the current situation
# * `ACTION` - An action to execute (e.g., a tool)
# * `OBSERVATION` - A generated observation (typically the output of a tool)
#
# Note that in this example, the `OBSERVATION` will be provided by us and not the LLM. This allows for a more simplified example as it would otherwise need quite a bit of code to add this observation.
#
# ReAct is mostly about prompting the LLM, so that's what we are going to do! The `ReAct` class consists of three functions:
#
# * `system_prompt` - The ReAct prompt
# * `parse_react` - Parse the LLM generated `THOUGHT` and `ACTION` so that they are separated for tool usage
# * `format_observation` - Create the `OBSERVATION` based on the output of the tool
#
# We instruct the `TinyAgent` to always use an `ACTION` and that if it does not need a tool, it can simply return it as:
#
# * `"final_answer"` - The final answer as text that **stops** the `TinyAgent` from running

# %%
import re
from illustrated_agents.chapters.ch2 import Response

class ReAct:
    """ReAct module."""

    def __init__(self, max_steps: int = 10):
        """Initialize ReAct module.

        Arguments:
            max_steps: Maximum number of ReAct steps to perform.
        """
        self.max_steps = max_steps

    @property
    def prompt(self) -> str:
        return """
# ReAct (Reason and Act)

You are a ReAct agent that performs exactly ONE step per turn.

## ReAct Format

You use the following format for each step:

THOUGHT: [Your reasoning about what to do next]
ACTION:
{
    "tool": "a_tool_name",
    "kwargs": {"param": "value"},
}

An observation will be provided after each action. You do not generate the observation yourself.

## ReAct Completion

To provide the final answer to the task, use an action blob with "tool": "final_answer" tool. 
It is the only way to complete the task, else you will be stuck on a loop. 
So your final output should look like this:

ACTION:
{
    "tool": "final_answer",
    "kwargs": "insert your final answer here"
}

Use the `final_answer` tool when you are completely done with all subtasks and have the final answer ready.
You can also use `final_answer` to directly reply to a user's question without using any other tools.

"""

    def parse(self, response: Response) -> Response:
        """Parse a ReAct formatted response into THOUGHT and ACTION."""
        text = response.content

        # The patterns for each section
        patterns = {
            "THOUGHT": r"THOUGHT:\s*(.+?)(?=ACTION:|OBSERVATION:|$)",
            "ACTION": r"ACTION:\s*(.+?)(?=THOUGHT:|OBSERVATION:|$)",
        }

        # Extract each section using regex
        result = {}
        for key, pattern in patterns.items():
            match = re.search(pattern, text, re.DOTALL)
            result[key] = match.group(1).strip() if match else ""

        # Update Response and extract only the action
        response.content = result["ACTION"]
        response.reasoning = result["THOUGHT"]
        return response

# %% [markdown]
# There is a lot happening there, so let's go through each function step-by-step starting with the prompt. Since ReAct is mostly a prompting technique, the prompt in itself is the most important step. The prompt, which we crafted through careful trial and error, has several components that describe how your `TinyAgent` should behave. Below, we have annotated this function for you so it is clear what the highlights are. Note that we might update prompt slight, but the general idea should remain the same:

# %%
from illustrated_agents.chapters.ch6 import react_prompt_annotated; react_prompt_annotated
# Out:
# <style>
# pre{line-height:1.5em!important}
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .ca-08057e07 .hll { background-color: #6e7681 }
# .ca-08057e07 { background: #0d1117; color: #E6EDF3 }
# .ca-08057e07 .c { color: #8B949E; font-style: italic } /* Comment */
# .ca-08057e07 .err { color: #F85149 } /* Error */
# .ca-08057e07 .esc { color: #E6EDF3 } /* Escape */
# .ca-08057e07 .g { color: #E6EDF3 } /* Generic */
# .ca-08057e07 .k { color: #FF7B72 } /* Keyword */
# .ca-08057e07 .l { color: #A5D6FF } /* Literal */
# .ca-08057e07 .n { color: #E6EDF3 } /* Name */
# .ca-08057e07 .o { color: #FF7B72; font-weight: bold } /* Operator */
# .ca-08057e07 .x { color: #E6EDF3 } /* Other */
# .ca-08057e07 .p { color: #E6EDF3 } /* Punctuation */
# .ca-08057e07 .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .ca-08057e07 .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .ca-08057e07 .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .ca-08057e07 .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .ca-08057e07 .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .ca-08057e07 .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .ca-08057e07 .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .ca-08057e07 .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .ca-08057e07 .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .ca-08057e07 .gr { color: #FFA198 } /* Generic.Error */
# .ca-08057e07 .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .ca-08057e07 .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .ca-08057e07 .go { color: #8B949E } /* Generic.Output */
# .ca-08057e07 .gp { color: #8B949E } /* Generic.Prompt */
# .ca-08057e07 .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .ca-08057e07 .gu { color: #79C0FF } /* Generic.Subheading */
# .ca-08057e07 .gt { color: #FF7B72 } /* Generic.Traceback */
# .ca-08057e07 .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .ca-08057e07 .kc { color: #79C0FF } /* Keyword.Constant */
# .ca-08057e07 .kd { color: #FF7B72 } /* Keyword.Declaration */
# .ca-08057e07 .kn { color: #FF7B72 } /* Keyword.Namespace */
# .ca-08057e07 .kp { color: #79C0FF } /* Keyword.Pseudo */
# .ca-08057e07 .kr { color: #FF7B72 } /* Keyword.Reserved */
# .ca-08057e07 .kt { color: #FF7B72 } /* Keyword.Type */
# .ca-08057e07 .ld { color: #79C0FF } /* Literal.Date */
# .ca-08057e07 .m { color: #A5D6FF } /* Literal.Number */
# .ca-08057e07 .s { color: #A5D6FF } /* Literal.String */
# .ca-08057e07 .na { color: #E6EDF3 } /* Name.Attribute */
# .ca-08057e07 .nb { color: #E6EDF3 } /* Name.Builtin */
# .ca-08057e07 .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .ca-08057e07 .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .ca-08057e07 .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .ca-08057e07 .ni { color: #FFA657 } /* Name.Entity */
# .ca-08057e07 .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .ca-08057e07 .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .ca-08057e07 .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .ca-08057e07 .nn { color: #FF7B72 } /* Name.Namespace */
# .ca-08057e07 .nx { color: #E6EDF3 } /* Name.Other */
# .ca-08057e07 .py { color: #79C0FF } /* Name.Property */
# .ca-08057e07 .nt { color: #7EE787 } /* Name.Tag */
# .ca-08057e07 .nv { color: #79C0FF } /* Name.Variable */
# .ca-08057e07 .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .ca-08057e07 .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .ca-08057e07 .w { color: #6E7681 } /* Text.Whitespace */
# .ca-08057e07 .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .ca-08057e07 .mf { color: #A5D6FF } /* Literal.Number.Float */
# .ca-08057e07 .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .ca-08057e07 .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .ca-08057e07 .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .ca-08057e07 .sa { color: #79C0FF } /* Literal.String.Affix */
# .ca-08057e07 .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .ca-08057e07 .sc { color: #A5D6FF } /* Literal.String.Char */
# .ca-08057e07 .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .ca-08057e07 .sd { color: #A5D6FF } /* Literal.String.Doc */
# .ca-08057e07 .s2 { color: #A5D6FF } /* Literal.String.Double */
# .ca-08057e07 .se { color: #79C0FF } /* Literal.String.Escape */
# .ca-08057e07 .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .ca-08057e07 .si { color: #A5D6FF } /* Literal.String.Interpol */
# .ca-08057e07 .sx { color: #A5D6FF } /* Literal.String.Other */
# .ca-08057e07 .sr { color: #79C0FF } /* Literal.String.Regex */
# .ca-08057e07 .s1 { color: #A5D6FF } /* Literal.String.Single */
# .ca-08057e07 .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .ca-08057e07 .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .ca-08057e07 .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .ca-08057e07 .vc { color: #79C0FF } /* Name.Variable.Class */
# .ca-08057e07 .vg { color: #79C0FF } /* Name.Variable.Global */
# .ca-08057e07 .vi { color: #79C0FF } /* Name.Variable.Instance */
# .ca-08057e07 .vm { color: #79C0FF } /* Name.Variable.Magic */
# .ca-08057e07 .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .ca-08057e07{background:#0d1117!important;color:#e6edf3!important;font-size:14px}
# .ca-08057e07 pre{margin:0;padding:0;line-height:1.5em!important;background:#0d1117!important;color:#e6edf3!important}
# .ca-08057e07 code{background:#0d1117!important;color:#e6edf3!important}
# .ca-08057e07 .hll{background:#3d4626!important;display:block;width:100%}
# .ca-08057e07 .linenos{background:#0d1117!important;color:#e6edf3!important}
# </style>
# <div style="display:inline-flex;align-items:flex-start;background:#0d1117;border-radius:8px;border:1px solid #444;margin:10px 0;font-family:monospace;font-size:14px;line-height:1.5em">
# <div style="flex:3;overflow-x:auto;background:#0d1117"><div class="ca-08057e07"><pre><span class="linenos"> 1</span>    <span class="nd">@property</span>
# <span class="linenos"> 2</span>    <span class="k">def</span><span class="w"> </span><span class="nf">prompt</span><span class="p">(</span><span class="bp">self</span><span class="p">)</span> <span class="o">-&gt;</span> <span class="nb">str</span><span class="p">:</span>
# <span class="linenos"> 3</span>        <span class="k">return</span> <span class="s2">"""</span>
# <span class="linenos"> 4</span><span class="s2"># ReAct (Reason and Act)</span>
# <span class="linenos"> 5</span>
# <span class="hll"><span class="linenos"> 6</span><span class="s2">You are a ReAct agent that performs exactly ONE step per turn.</span>
# </span><span class="hll"><span class="linenos"> 7</span>
# </span><span class="linenos"> 8</span><span class="s2">## ReAct Format</span>
# <span class="linenos"> 9</span>
# <span class="linenos">10</span><span class="s2">You use the following format for each step:</span>
# <span class="linenos">11</span>
# <span class="hll"><span class="linenos">12</span><span class="s2">THOUGHT: [Your reasoning about what to do next]</span>
# </span><span class="hll"><span class="linenos">13</span><span class="s2">ACTION:</span>
# </span><span class="hll"><span class="linenos">14</span><span class="s2">{</span>
# </span><span class="hll"><span class="linenos">15</span><span class="s2">    "tool": "a_tool_name",</span>
# </span><span class="hll"><span class="linenos">16</span><span class="s2">    "kwargs": {"param": "value"},</span>
# </span><span class="hll"><span class="linenos">17</span><span class="s2">}</span>

# %% [markdown]
# The `parse_react` function is needed to parse the strings that contain THOUGHT and ACTION into separate entities:

# %%
from illustrated_agents.chapters.ch6 import react_parse_annotated; react_parse_annotated
# Out:
# <style>
# pre{line-height:1.5em!important}
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .ca-ef631add .hll { background-color: #6e7681 }
# .ca-ef631add { background: #0d1117; color: #E6EDF3 }
# .ca-ef631add .c { color: #8B949E; font-style: italic } /* Comment */
# .ca-ef631add .err { color: #F85149 } /* Error */
# .ca-ef631add .esc { color: #E6EDF3 } /* Escape */
# .ca-ef631add .g { color: #E6EDF3 } /* Generic */
# .ca-ef631add .k { color: #FF7B72 } /* Keyword */
# .ca-ef631add .l { color: #A5D6FF } /* Literal */
# .ca-ef631add .n { color: #E6EDF3 } /* Name */
# .ca-ef631add .o { color: #FF7B72; font-weight: bold } /* Operator */
# .ca-ef631add .x { color: #E6EDF3 } /* Other */
# .ca-ef631add .p { color: #E6EDF3 } /* Punctuation */
# .ca-ef631add .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .ca-ef631add .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .ca-ef631add .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .ca-ef631add .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .ca-ef631add .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .ca-ef631add .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .ca-ef631add .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .ca-ef631add .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .ca-ef631add .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .ca-ef631add .gr { color: #FFA198 } /* Generic.Error */
# .ca-ef631add .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .ca-ef631add .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .ca-ef631add .go { color: #8B949E } /* Generic.Output */
# .ca-ef631add .gp { color: #8B949E } /* Generic.Prompt */
# .ca-ef631add .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .ca-ef631add .gu { color: #79C0FF } /* Generic.Subheading */
# .ca-ef631add .gt { color: #FF7B72 } /* Generic.Traceback */
# .ca-ef631add .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .ca-ef631add .kc { color: #79C0FF } /* Keyword.Constant */
# .ca-ef631add .kd { color: #FF7B72 } /* Keyword.Declaration */
# .ca-ef631add .kn { color: #FF7B72 } /* Keyword.Namespace */
# .ca-ef631add .kp { color: #79C0FF } /* Keyword.Pseudo */
# .ca-ef631add .kr { color: #FF7B72 } /* Keyword.Reserved */
# .ca-ef631add .kt { color: #FF7B72 } /* Keyword.Type */
# .ca-ef631add .ld { color: #79C0FF } /* Literal.Date */
# .ca-ef631add .m { color: #A5D6FF } /* Literal.Number */
# .ca-ef631add .s { color: #A5D6FF } /* Literal.String */
# .ca-ef631add .na { color: #E6EDF3 } /* Name.Attribute */
# .ca-ef631add .nb { color: #E6EDF3 } /* Name.Builtin */
# .ca-ef631add .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .ca-ef631add .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .ca-ef631add .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .ca-ef631add .ni { color: #FFA657 } /* Name.Entity */
# .ca-ef631add .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .ca-ef631add .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .ca-ef631add .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .ca-ef631add .nn { color: #FF7B72 } /* Name.Namespace */
# .ca-ef631add .nx { color: #E6EDF3 } /* Name.Other */
# .ca-ef631add .py { color: #79C0FF } /* Name.Property */
# .ca-ef631add .nt { color: #7EE787 } /* Name.Tag */
# .ca-ef631add .nv { color: #79C0FF } /* Name.Variable */
# .ca-ef631add .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .ca-ef631add .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .ca-ef631add .w { color: #6E7681 } /* Text.Whitespace */
# .ca-ef631add .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .ca-ef631add .mf { color: #A5D6FF } /* Literal.Number.Float */
# .ca-ef631add .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .ca-ef631add .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .ca-ef631add .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .ca-ef631add .sa { color: #79C0FF } /* Literal.String.Affix */
# .ca-ef631add .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .ca-ef631add .sc { color: #A5D6FF } /* Literal.String.Char */
# .ca-ef631add .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .ca-ef631add .sd { color: #A5D6FF } /* Literal.String.Doc */
# .ca-ef631add .s2 { color: #A5D6FF } /* Literal.String.Double */
# .ca-ef631add .se { color: #79C0FF } /* Literal.String.Escape */
# .ca-ef631add .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .ca-ef631add .si { color: #A5D6FF } /* Literal.String.Interpol */
# .ca-ef631add .sx { color: #A5D6FF } /* Literal.String.Other */
# .ca-ef631add .sr { color: #79C0FF } /* Literal.String.Regex */
# .ca-ef631add .s1 { color: #A5D6FF } /* Literal.String.Single */
# .ca-ef631add .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .ca-ef631add .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .ca-ef631add .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .ca-ef631add .vc { color: #79C0FF } /* Name.Variable.Class */
# .ca-ef631add .vg { color: #79C0FF } /* Name.Variable.Global */
# .ca-ef631add .vi { color: #79C0FF } /* Name.Variable.Instance */
# .ca-ef631add .vm { color: #79C0FF } /* Name.Variable.Magic */
# .ca-ef631add .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .ca-ef631add{background:#0d1117!important;color:#e6edf3!important;font-size:14px}
# .ca-ef631add pre{margin:0;padding:0;line-height:1.5em!important;background:#0d1117!important;color:#e6edf3!important}
# .ca-ef631add code{background:#0d1117!important;color:#e6edf3!important}
# .ca-ef631add .hll{background:#3d4626!important;display:block;width:100%}
# .ca-ef631add .linenos{background:#0d1117!important;color:#e6edf3!important}
# </style>
# <div style="display:inline-flex;align-items:flex-start;background:#0d1117;border-radius:8px;border:1px solid #444;margin:10px 0;font-family:monospace;font-size:14px;line-height:1.5em">
# <div style="flex:3;overflow-x:auto;background:#0d1117"><div class="ca-ef631add"><pre><span class="linenos"> 1</span><span class="k">def</span><span class="w"> </span><span class="nf">parse</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">response</span><span class="p">:</span> <span class="n">Response</span><span class="p">)</span> <span class="o">-&gt;</span> <span class="n">Response</span><span class="p">:</span>
# <span class="linenos"> 2</span><span class="w">    </span><span class="sd">"""Parse a ReAct formatted response into THOUGHT and ACTION."""</span>
# <span class="linenos"> 3</span>    <span class="n">text</span> <span class="o">=</span> <span class="n">response</span><span class="o">.</span><span class="n">content</span>
# <span class="linenos"> 4</span>
# <span class="linenos"> 5</span>    <span class="c1"># The patterns for each section</span>
# <span class="hll"><span class="linenos"> 6</span>    <span class="n">patterns</span> <span class="o">=</span> <span class="p">{</span>
# </span><span class="hll"><span class="linenos"> 7</span>        <span class="s2">"THOUGHT"</span><span class="p">:</span> <span class="sa">r</span><span class="s2">"THOUGHT:\s*(.+?)(?=ACTION:|OBSERVATION:|$)"</span><span class="p">,</span>
# </span><span class="hll"><span class="linenos"> 8</span>        <span class="s2">"ACTION"</span><span class="p">:</span> <span class="sa">r</span><span class="s2">"ACTION:\s*(.+?)(?=THOUGHT:|OBSERVATION:|$)"</span><span class="p">,</span>
# </span><span class="hll"><span class="linenos"> 9</span>    <span class="p">}</span>
# </span><span class="linenos">10</span>
# <span class="

# %% [markdown]
# ---
#
# 💡 **NOTE 1**: For execution, we only return the `ACTION` section since that's what we need to execute tools and provide answers.
# The THOUGHT section is useful for interpretability but not needed for execution.
#
# 💡 **NOTE 2**: Use regular expressions (`re`) is definitely not the most stable way of doing this! What if the LLM makes a small mistake and uses "*THOUGH:*" instead of "*THOUGHT:*"? This will not capture and that is on purpose. We want to showcase the most minimal way of approaching this and the downsides of doing this. Likewise, we could construct a 100+ line function/class that is more robust but defeats the purpose of an educational example. That said, this downside also nicely demonstrates why native tool calling is more robust since the LLM has seen very specific tokens it can use to perform tool calling. This drastically reduces the error rate but makes an Agent a bit more of a blackbox. Don't worry, we're definitely also showing you how to do this in `chapter06_native_react.ipynb`.
#
# ---

# %% [markdown]
# ## 4 - Updating `agent.py`
#
# There are several changes needed to `TinyAgent` that requires changes throughout the class. In particular:
#
# * `__init__` -- We need to add the prompt of the `ReAct` to the system prompt
# * `run` -- Your `TinyAgent` now runs for a number of steps, defined by `ReAct`
# * `_step` -- Now performs a single step of the `ReAct` loop (**THOUGHT**/**ACTION**/**OBSERVATION**)
# * `_execute_action` -- A function to parse the tool call from the **ACTION** step.

# %%
from illustrated_agents.chapters.ch2 import Response, Trajectory
from illustrated_agents.chapters.ch4 import Memory
from illustrated_agents.chapters.ch5 import Tools


class TinyAgent:
    """A minimal, modular, and educational agent framework."""

    def __init__(self, llm: LLM, memory: Memory, tools: Tools, planner: ReAct):
        self.llm = llm
        self.memory = memory
        self.tools = tools
        self.planner = planner

        self.trajectory = Trajectory()

        # Build system prompt with all components
        system_prompt = "You are a helpful assistant.\n\n"
        system_prompt += self.planner.prompt
        system_prompt += self.tools.prompt
        self.memory.add("system", system_prompt)

    def run(self, task: str) -> str:
        """Run the agent on a task."""
        self.memory.add("user", task)
        self.trajectory.initialize(task)

        # *Autonomy* loop
        for step in range(self.planner.max_steps):
            result = self._step()
            if result is not None:
                return result

    def _step(self) -> str | None:
        """Perform a single step."""
        # THOUGHT: Generate response and add to memory
        response = self.llm.generate(
            self.memory.get_messages(), tools=self.tools.schemas
        )
        self.memory.add(
            "assistant", response.content, tool_call=response.tool_call
        )

        # Tool parsing
        response = self.planner.parse(response)
        response = self.tools.parse(response)

        # ANSWER: Stopping mechanism
        if self.tools.is_done(response):
            self.trajectory.add(response)
            return response.content

        return self._execute_action(response)

    def _execute_action(self, response: Response) -> None:
        """Execute a tool action."""

        # ACTION: execute tools
        result = self.tools.execute(response)

        # OBSERVATION: add tool results to memory and display
        role, observation = self.tools.observation(result)
        self.memory.add(role, observation)
        self.trajectory.add(response, observation)

        return None

# %% [markdown]
# Although we can show the diff like we did before, this time there are so many changes! Instead, let's go through each function and describe how they are used, starting with the `__init__`:

# %%
from illustrated_agents.chapters.ch6 import tinyagent_init_annotated; tinyagent_init_annotated
# Out:
# <style>
# pre{line-height:1.5em!important}
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .ca-25698f50 .hll { background-color: #6e7681 }
# .ca-25698f50 { background: #0d1117; color: #E6EDF3 }
# .ca-25698f50 .c { color: #8B949E; font-style: italic } /* Comment */
# .ca-25698f50 .err { color: #F85149 } /* Error */
# .ca-25698f50 .esc { color: #E6EDF3 } /* Escape */
# .ca-25698f50 .g { color: #E6EDF3 } /* Generic */
# .ca-25698f50 .k { color: #FF7B72 } /* Keyword */
# .ca-25698f50 .l { color: #A5D6FF } /* Literal */
# .ca-25698f50 .n { color: #E6EDF3 } /* Name */
# .ca-25698f50 .o { color: #FF7B72; font-weight: bold } /* Operator */
# .ca-25698f50 .x { color: #E6EDF3 } /* Other */
# .ca-25698f50 .p { color: #E6EDF3 } /* Punctuation */
# .ca-25698f50 .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .ca-25698f50 .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .ca-25698f50 .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .ca-25698f50 .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .ca-25698f50 .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .ca-25698f50 .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .ca-25698f50 .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .ca-25698f50 .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .ca-25698f50 .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .ca-25698f50 .gr { color: #FFA198 } /* Generic.Error */
# .ca-25698f50 .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .ca-25698f50 .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .ca-25698f50 .go { color: #8B949E } /* Generic.Output */
# .ca-25698f50 .gp { color: #8B949E } /* Generic.Prompt */
# .ca-25698f50 .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .ca-25698f50 .gu { color: #79C0FF } /* Generic.Subheading */
# .ca-25698f50 .gt { color: #FF7B72 } /* Generic.Traceback */
# .ca-25698f50 .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .ca-25698f50 .kc { color: #79C0FF } /* Keyword.Constant */
# .ca-25698f50 .kd { color: #FF7B72 } /* Keyword.Declaration */
# .ca-25698f50 .kn { color: #FF7B72 } /* Keyword.Namespace */
# .ca-25698f50 .kp { color: #79C0FF } /* Keyword.Pseudo */
# .ca-25698f50 .kr { color: #FF7B72 } /* Keyword.Reserved */
# .ca-25698f50 .kt { color: #FF7B72 } /* Keyword.Type */
# .ca-25698f50 .ld { color: #79C0FF } /* Literal.Date */
# .ca-25698f50 .m { color: #A5D6FF } /* Literal.Number */
# .ca-25698f50 .s { color: #A5D6FF } /* Literal.String */
# .ca-25698f50 .na { color: #E6EDF3 } /* Name.Attribute */
# .ca-25698f50 .nb { color: #E6EDF3 } /* Name.Builtin */
# .ca-25698f50 .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .ca-25698f50 .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .ca-25698f50 .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .ca-25698f50 .ni { color: #FFA657 } /* Name.Entity */
# .ca-25698f50 .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .ca-25698f50 .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .ca-25698f50 .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .ca-25698f50 .nn { color: #FF7B72 } /* Name.Namespace */
# .ca-25698f50 .nx { color: #E6EDF3 } /* Name.Other */
# .ca-25698f50 .py { color: #79C0FF } /* Name.Property */
# .ca-25698f50 .nt { color: #7EE787 } /* Name.Tag */
# .ca-25698f50 .nv { color: #79C0FF } /* Name.Variable */
# .ca-25698f50 .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .ca-25698f50 .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .ca-25698f50 .w { color: #6E7681 } /* Text.Whitespace */
# .ca-25698f50 .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .ca-25698f50 .mf { color: #A5D6FF } /* Literal.Number.Float */
# .ca-25698f50 .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .ca-25698f50 .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .ca-25698f50 .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .ca-25698f50 .sa { color: #79C0FF } /* Literal.String.Affix */
# .ca-25698f50 .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .ca-25698f50 .sc { color: #A5D6FF } /* Literal.String.Char */
# .ca-25698f50 .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .ca-25698f50 .sd { color: #A5D6FF } /* Literal.String.Doc */
# .ca-25698f50 .s2 { color: #A5D6FF } /* Literal.String.Double */
# .ca-25698f50 .se { color: #79C0FF } /* Literal.String.Escape */
# .ca-25698f50 .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .ca-25698f50 .si { color: #A5D6FF } /* Literal.String.Interpol */
# .ca-25698f50 .sx { color: #A5D6FF } /* Literal.String.Other */
# .ca-25698f50 .sr { color: #79C0FF } /* Literal.String.Regex */
# .ca-25698f50 .s1 { color: #A5D6FF } /* Literal.String.Single */
# .ca-25698f50 .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .ca-25698f50 .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .ca-25698f50 .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .ca-25698f50 .vc { color: #79C0FF } /* Name.Variable.Class */
# .ca-25698f50 .vg { color: #79C0FF } /* Name.Variable.Global */
# .ca-25698f50 .vi { color: #79C0FF } /* Name.Variable.Instance */
# .ca-25698f50 .vm { color: #79C0FF } /* Name.Variable.Magic */
# .ca-25698f50 .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .ca-25698f50{background:#0d1117!important;color:#e6edf3!important;font-size:14px}
# .ca-25698f50 pre{margin:0;padding:0;line-height:1.5em!important;background:#0d1117!important;color:#e6edf3!important}
# .ca-25698f50 code{background:#0d1117!important;color:#e6edf3!important}
# .ca-25698f50 .hll{background:#3d4626!important;display:block;width:100%}
# .ca-25698f50 .linenos{background:#0d1117!important;color:#e6edf3!important}
# </style>
# <div style="display:inline-flex;align-items:flex-start;background:#0d1117;border-radius:8px;border:1px solid #444;margin:10px 0;font-family:monospace;font-size:14px;line-height:1.5em">
# <div style="flex:3;overflow-x:auto;background:#0d1117"><div class="ca-25698f50"><pre><span class="linenos"> 1</span><span class="k">def</span><span class="w"> </span><span class="fm">__init__</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">llm</span><span class="p">:</span> <span class="n">LLM</span><span class="p">,</span> <span class="n">memory</span><span class="p">:</span> <span class="n">Memory</span><span class="p">,</span> <span class="n">tools</span><span class="p">:</span> <span class="n">Tools</span><span class="p">,</span> <span class="n">planner</span><span class="p">:</span> <span class="n">ReAct</span><span class="p">):</span>
# <span class="linenos"> 2</span>    <span class="bp">self</span><span class="o">.</span><span class="n">llm</span> <span class="o">=</span> <span class="n">llm</span>
# <span class="linenos"> 3</span>    <span class="bp">self</span><span class="o">.</span><span class="n">memory</span> <span class="o">=</span> <span class="n">memory</span>
# <span class="linenos"> 4</span>    <span class="bp">self</span><span class="o">.</span><span class="n">tools</span> <span class="o">=</span> <span class="n">tools</span>
# <span class="linenos"> 5</span>    <span class="bp">self</span><span class="o">.</span><span class="n">planner</span> <span class="o">=</span> <span class="n">planner</span>
# <span class="linenos"> 6</span>
# <span class="linenos"> 7</span>    <span class="bp">self</span><span class="o">.</span><span class="n">trajectory</span> <span class="o">=</span> <span class="n">Trajectory</span><span class="p">()</span>
# <span class="linenos"> 8</span>
# <span class=

# %% [markdown]
# Next, let's explore the `run` function where two interesting actions take place:

# %%
from illustrated_agents.chapters.ch6 import tinyagent_run_annotated; tinyagent_run_annotated
# Out:
# <style>
# pre{line-height:1.5em!important}
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .ca-d155595c .hll { background-color: #6e7681 }
# .ca-d155595c { background: #0d1117; color: #E6EDF3 }
# .ca-d155595c .c { color: #8B949E; font-style: italic } /* Comment */
# .ca-d155595c .err { color: #F85149 } /* Error */
# .ca-d155595c .esc { color: #E6EDF3 } /* Escape */
# .ca-d155595c .g { color: #E6EDF3 } /* Generic */
# .ca-d155595c .k { color: #FF7B72 } /* Keyword */
# .ca-d155595c .l { color: #A5D6FF } /* Literal */
# .ca-d155595c .n { color: #E6EDF3 } /* Name */
# .ca-d155595c .o { color: #FF7B72; font-weight: bold } /* Operator */
# .ca-d155595c .x { color: #E6EDF3 } /* Other */
# .ca-d155595c .p { color: #E6EDF3 } /* Punctuation */
# .ca-d155595c .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .ca-d155595c .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .ca-d155595c .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .ca-d155595c .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .ca-d155595c .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .ca-d155595c .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .ca-d155595c .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .ca-d155595c .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .ca-d155595c .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .ca-d155595c .gr { color: #FFA198 } /* Generic.Error */
# .ca-d155595c .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .ca-d155595c .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .ca-d155595c .go { color: #8B949E } /* Generic.Output */
# .ca-d155595c .gp { color: #8B949E } /* Generic.Prompt */
# .ca-d155595c .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .ca-d155595c .gu { color: #79C0FF } /* Generic.Subheading */
# .ca-d155595c .gt { color: #FF7B72 } /* Generic.Traceback */
# .ca-d155595c .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .ca-d155595c .kc { color: #79C0FF } /* Keyword.Constant */
# .ca-d155595c .kd { color: #FF7B72 } /* Keyword.Declaration */
# .ca-d155595c .kn { color: #FF7B72 } /* Keyword.Namespace */
# .ca-d155595c .kp { color: #79C0FF } /* Keyword.Pseudo */
# .ca-d155595c .kr { color: #FF7B72 } /* Keyword.Reserved */
# .ca-d155595c .kt { color: #FF7B72 } /* Keyword.Type */
# .ca-d155595c .ld { color: #79C0FF } /* Literal.Date */
# .ca-d155595c .m { color: #A5D6FF } /* Literal.Number */
# .ca-d155595c .s { color: #A5D6FF } /* Literal.String */
# .ca-d155595c .na { color: #E6EDF3 } /* Name.Attribute */
# .ca-d155595c .nb { color: #E6EDF3 } /* Name.Builtin */
# .ca-d155595c .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .ca-d155595c .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .ca-d155595c .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .ca-d155595c .ni { color: #FFA657 } /* Name.Entity */
# .ca-d155595c .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .ca-d155595c .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .ca-d155595c .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .ca-d155595c .nn { color: #FF7B72 } /* Name.Namespace */
# .ca-d155595c .nx { color: #E6EDF3 } /* Name.Other */
# .ca-d155595c .py { color: #79C0FF } /* Name.Property */
# .ca-d155595c .nt { color: #7EE787 } /* Name.Tag */
# .ca-d155595c .nv { color: #79C0FF } /* Name.Variable */
# .ca-d155595c .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .ca-d155595c .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .ca-d155595c .w { color: #6E7681 } /* Text.Whitespace */
# .ca-d155595c .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .ca-d155595c .mf { color: #A5D6FF } /* Literal.Number.Float */
# .ca-d155595c .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .ca-d155595c .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .ca-d155595c .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .ca-d155595c .sa { color: #79C0FF } /* Literal.String.Affix */
# .ca-d155595c .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .ca-d155595c .sc { color: #A5D6FF } /* Literal.String.Char */
# .ca-d155595c .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .ca-d155595c .sd { color: #A5D6FF } /* Literal.String.Doc */
# .ca-d155595c .s2 { color: #A5D6FF } /* Literal.String.Double */
# .ca-d155595c .se { color: #79C0FF } /* Literal.String.Escape */
# .ca-d155595c .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .ca-d155595c .si { color: #A5D6FF } /* Literal.String.Interpol */
# .ca-d155595c .sx { color: #A5D6FF } /* Literal.String.Other */
# .ca-d155595c .sr { color: #79C0FF } /* Literal.String.Regex */
# .ca-d155595c .s1 { color: #A5D6FF } /* Literal.String.Single */
# .ca-d155595c .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .ca-d155595c .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .ca-d155595c .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .ca-d155595c .vc { color: #79C0FF } /* Name.Variable.Class */
# .ca-d155595c .vg { color: #79C0FF } /* Name.Variable.Global */
# .ca-d155595c .vi { color: #79C0FF } /* Name.Variable.Instance */
# .ca-d155595c .vm { color: #79C0FF } /* Name.Variable.Magic */
# .ca-d155595c .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .ca-d155595c{background:#0d1117!important;color:#e6edf3!important;font-size:14px}
# .ca-d155595c pre{margin:0;padding:0;line-height:1.5em!important;background:#0d1117!important;color:#e6edf3!important}
# .ca-d155595c code{background:#0d1117!important;color:#e6edf3!important}
# .ca-d155595c .hll{background:#3d4626!important;display:block;width:100%}
# .ca-d155595c .linenos{background:#0d1117!important;color:#e6edf3!important}
# </style>
# <div style="display:inline-flex;align-items:flex-start;background:#0d1117;border-radius:8px;border:1px solid #444;margin:10px 0;font-family:monospace;font-size:14px;line-height:1.5em">
# <div style="flex:3;overflow-x:auto;background:#0d1117"><div class="ca-d155595c"><pre><span class="linenos"> 1</span><span class="k">def</span><span class="w"> </span><span class="nf">run</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">task</span><span class="p">:</span> <span class="nb">str</span><span class="p">)</span> <span class="o">-&gt;</span> <span class="nb">str</span><span class="p">:</span>
# <span class="linenos"> 2</span><span class="w">    </span><span class="sd">"""Run the agent on a task."""</span>
# <span class="hll"><span class="linenos"> 3</span>    <span class="bp">self</span><span class="o">.</span><span class="n">memory</span><span class="o">.</span><span class="n">add</span><span class="p">(</span><span class="s2">"user"</span><span class="p">,</span> <span class="n">task</span><span class="p">)</span>
# </span><span class="linenos"> 4</span>    <span class="bp">self</span><span class="o">.</span><span class="n">trajectory</span><span class="o">.</span><span class="n">initialize</span><span class="p">(</span><span class="n">task</span><span class="p">)</span>
# <span class="linenos"> 5</span>
# <span class="linenos"> 6</span>    <span class="c1"># *Autonomy* loop</span>
# <span class="hll"><span class="linenos"> 7</span>    <span class="k">for</span> <span class="n">step</span> <span class="ow">in</span> <span class="nb">range</span><span class="p">(</span><span class="bp">self</span><span class="o">.</span><span class="n">planner</span><span class="o">.</span><span class="n">max_steps</span><span class="p">):</span>
# </span><span class="hll"><span class="linenos"> 8</span>

# %% [markdown]
# Next, the `_step` is where much of the processing happens and now shows an interesting structure:

# %%
from illustrated_agents.chapters.ch6 import tinyagent_step_annotated; tinyagent_step_annotated
# Out:
# <style>
# pre{line-height:1.5em!important}
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .ca-5d7b4786 .hll { background-color: #6e7681 }
# .ca-5d7b4786 { background: #0d1117; color: #E6EDF3 }
# .ca-5d7b4786 .c { color: #8B949E; font-style: italic } /* Comment */
# .ca-5d7b4786 .err { color: #F85149 } /* Error */
# .ca-5d7b4786 .esc { color: #E6EDF3 } /* Escape */
# .ca-5d7b4786 .g { color: #E6EDF3 } /* Generic */
# .ca-5d7b4786 .k { color: #FF7B72 } /* Keyword */
# .ca-5d7b4786 .l { color: #A5D6FF } /* Literal */
# .ca-5d7b4786 .n { color: #E6EDF3 } /* Name */
# .ca-5d7b4786 .o { color: #FF7B72; font-weight: bold } /* Operator */
# .ca-5d7b4786 .x { color: #E6EDF3 } /* Other */
# .ca-5d7b4786 .p { color: #E6EDF3 } /* Punctuation */
# .ca-5d7b4786 .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .ca-5d7b4786 .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .ca-5d7b4786 .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .ca-5d7b4786 .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .ca-5d7b4786 .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .ca-5d7b4786 .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .ca-5d7b4786 .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .ca-5d7b4786 .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .ca-5d7b4786 .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .ca-5d7b4786 .gr { color: #FFA198 } /* Generic.Error */
# .ca-5d7b4786 .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .ca-5d7b4786 .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .ca-5d7b4786 .go { color: #8B949E } /* Generic.Output */
# .ca-5d7b4786 .gp { color: #8B949E } /* Generic.Prompt */
# .ca-5d7b4786 .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .ca-5d7b4786 .gu { color: #79C0FF } /* Generic.Subheading */
# .ca-5d7b4786 .gt { color: #FF7B72 } /* Generic.Traceback */
# .ca-5d7b4786 .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .ca-5d7b4786 .kc { color: #79C0FF } /* Keyword.Constant */
# .ca-5d7b4786 .kd { color: #FF7B72 } /* Keyword.Declaration */
# .ca-5d7b4786 .kn { color: #FF7B72 } /* Keyword.Namespace */
# .ca-5d7b4786 .kp { color: #79C0FF } /* Keyword.Pseudo */
# .ca-5d7b4786 .kr { color: #FF7B72 } /* Keyword.Reserved */
# .ca-5d7b4786 .kt { color: #FF7B72 } /* Keyword.Type */
# .ca-5d7b4786 .ld { color: #79C0FF } /* Literal.Date */
# .ca-5d7b4786 .m { color: #A5D6FF } /* Literal.Number */
# .ca-5d7b4786 .s { color: #A5D6FF } /* Literal.String */
# .ca-5d7b4786 .na { color: #E6EDF3 } /* Name.Attribute */
# .ca-5d7b4786 .nb { color: #E6EDF3 } /* Name.Builtin */
# .ca-5d7b4786 .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .ca-5d7b4786 .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .ca-5d7b4786 .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .ca-5d7b4786 .ni { color: #FFA657 } /* Name.Entity */
# .ca-5d7b4786 .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .ca-5d7b4786 .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .ca-5d7b4786 .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .ca-5d7b4786 .nn { color: #FF7B72 } /* Name.Namespace */
# .ca-5d7b4786 .nx { color: #E6EDF3 } /* Name.Other */
# .ca-5d7b4786 .py { color: #79C0FF } /* Name.Property */
# .ca-5d7b4786 .nt { color: #7EE787 } /* Name.Tag */
# .ca-5d7b4786 .nv { color: #79C0FF } /* Name.Variable */
# .ca-5d7b4786 .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .ca-5d7b4786 .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .ca-5d7b4786 .w { color: #6E7681 } /* Text.Whitespace */
# .ca-5d7b4786 .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .ca-5d7b4786 .mf { color: #A5D6FF } /* Literal.Number.Float */
# .ca-5d7b4786 .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .ca-5d7b4786 .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .ca-5d7b4786 .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .ca-5d7b4786 .sa { color: #79C0FF } /* Literal.String.Affix */
# .ca-5d7b4786 .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .ca-5d7b4786 .sc { color: #A5D6FF } /* Literal.String.Char */
# .ca-5d7b4786 .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .ca-5d7b4786 .sd { color: #A5D6FF } /* Literal.String.Doc */
# .ca-5d7b4786 .s2 { color: #A5D6FF } /* Literal.String.Double */
# .ca-5d7b4786 .se { color: #79C0FF } /* Literal.String.Escape */
# .ca-5d7b4786 .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .ca-5d7b4786 .si { color: #A5D6FF } /* Literal.String.Interpol */
# .ca-5d7b4786 .sx { color: #A5D6FF } /* Literal.String.Other */
# .ca-5d7b4786 .sr { color: #79C0FF } /* Literal.String.Regex */
# .ca-5d7b4786 .s1 { color: #A5D6FF } /* Literal.String.Single */
# .ca-5d7b4786 .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .ca-5d7b4786 .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .ca-5d7b4786 .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .ca-5d7b4786 .vc { color: #79C0FF } /* Name.Variable.Class */
# .ca-5d7b4786 .vg { color: #79C0FF } /* Name.Variable.Global */
# .ca-5d7b4786 .vi { color: #79C0FF } /* Name.Variable.Instance */
# .ca-5d7b4786 .vm { color: #79C0FF } /* Name.Variable.Magic */
# .ca-5d7b4786 .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .ca-5d7b4786{background:#0d1117!important;color:#e6edf3!important;font-size:14px}
# .ca-5d7b4786 pre{margin:0;padding:0;line-height:1.5em!important;background:#0d1117!important;color:#e6edf3!important}
# .ca-5d7b4786 code{background:#0d1117!important;color:#e6edf3!important}
# .ca-5d7b4786 .hll{background:#3d4626!important;display:block;width:100%}
# .ca-5d7b4786 .linenos{background:#0d1117!important;color:#e6edf3!important}
# </style>
# <div style="display:inline-flex;align-items:flex-start;background:#0d1117;border-radius:8px;border:1px solid #444;margin:10px 0;font-family:monospace;font-size:14px;line-height:1.5em">
# <div style="flex:3;overflow-x:auto;background:#0d1117"><div class="ca-5d7b4786"><pre><span class="linenos"> 1</span><span class="k">def</span><span class="w"> </span><span class="nf">_step</span><span class="p">(</span><span class="bp">self</span><span class="p">)</span> <span class="o">-&gt;</span> <span class="nb">str</span> <span class="o">|</span> <span class="kc">None</span><span class="p">:</span>
# <span class="linenos"> 2</span><span class="w">    </span><span class="sd">"""Perform a single step."""</span>
# <span class="linenos"> 3</span>    <span class="c1"># THOUGHT: Generate response and add to memory</span>
# <span class="hll"><span class="linenos"> 4</span>    <span class="n">response</span> <span class="o">=</span> <span class="bp">self</span><span class="o">.</span><span class="n">llm</span><span class="o">.</span><span class="n">generate</span><span class="p">(</span>
# </span><span class="hll"><span class="linenos"> 5</span>        <span class="bp">self</span><span class="o">.</span><span class="n">memory</span><span class="o">.</span><span class="n">get_messages</span><span class="p">(),</span> <span class="n">tools</span><span class="o">=</span><span class="bp">self</span><span class="o">.</span><span class="n">tools</span><span class="o">.</span><span class="n">schemas</span>
# </span><span class="linenos"> 6</span>    <span class="p">)</span>
# <span class="linenos"> 7</span>    <span class="bp">self</span><span class="o">.</span><span class="n">memory</span><span class="o">.</span><span class="n">add</span><span class="p">(</span>
# <span class="hll"><span class="linenos"> 8</span>        <span class="s2">"assistant"</span><sp

# %% [markdown]
# Finally, the `_execute_action` processes the **ACTION** step:

# %%
from illustrated_agents.chapters.ch6 import tinyagent_action_annotated; tinyagent_action_annotated
# Out:
# <style>
# pre{line-height:1.5em!important}
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .ca-7ecf6037 .hll { background-color: #6e7681 }
# .ca-7ecf6037 { background: #0d1117; color: #E6EDF3 }
# .ca-7ecf6037 .c { color: #8B949E; font-style: italic } /* Comment */
# .ca-7ecf6037 .err { color: #F85149 } /* Error */
# .ca-7ecf6037 .esc { color: #E6EDF3 } /* Escape */
# .ca-7ecf6037 .g { color: #E6EDF3 } /* Generic */
# .ca-7ecf6037 .k { color: #FF7B72 } /* Keyword */
# .ca-7ecf6037 .l { color: #A5D6FF } /* Literal */
# .ca-7ecf6037 .n { color: #E6EDF3 } /* Name */
# .ca-7ecf6037 .o { color: #FF7B72; font-weight: bold } /* Operator */
# .ca-7ecf6037 .x { color: #E6EDF3 } /* Other */
# .ca-7ecf6037 .p { color: #E6EDF3 } /* Punctuation */
# .ca-7ecf6037 .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .ca-7ecf6037 .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .ca-7ecf6037 .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .ca-7ecf6037 .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .ca-7ecf6037 .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .ca-7ecf6037 .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .ca-7ecf6037 .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .ca-7ecf6037 .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .ca-7ecf6037 .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .ca-7ecf6037 .gr { color: #FFA198 } /* Generic.Error */
# .ca-7ecf6037 .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .ca-7ecf6037 .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .ca-7ecf6037 .go { color: #8B949E } /* Generic.Output */
# .ca-7ecf6037 .gp { color: #8B949E } /* Generic.Prompt */
# .ca-7ecf6037 .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .ca-7ecf6037 .gu { color: #79C0FF } /* Generic.Subheading */
# .ca-7ecf6037 .gt { color: #FF7B72 } /* Generic.Traceback */
# .ca-7ecf6037 .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .ca-7ecf6037 .kc { color: #79C0FF } /* Keyword.Constant */
# .ca-7ecf6037 .kd { color: #FF7B72 } /* Keyword.Declaration */
# .ca-7ecf6037 .kn { color: #FF7B72 } /* Keyword.Namespace */
# .ca-7ecf6037 .kp { color: #79C0FF } /* Keyword.Pseudo */
# .ca-7ecf6037 .kr { color: #FF7B72 } /* Keyword.Reserved */
# .ca-7ecf6037 .kt { color: #FF7B72 } /* Keyword.Type */
# .ca-7ecf6037 .ld { color: #79C0FF } /* Literal.Date */
# .ca-7ecf6037 .m { color: #A5D6FF } /* Literal.Number */
# .ca-7ecf6037 .s { color: #A5D6FF } /* Literal.String */
# .ca-7ecf6037 .na { color: #E6EDF3 } /* Name.Attribute */
# .ca-7ecf6037 .nb { color: #E6EDF3 } /* Name.Builtin */
# .ca-7ecf6037 .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .ca-7ecf6037 .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .ca-7ecf6037 .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .ca-7ecf6037 .ni { color: #FFA657 } /* Name.Entity */
# .ca-7ecf6037 .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .ca-7ecf6037 .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .ca-7ecf6037 .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .ca-7ecf6037 .nn { color: #FF7B72 } /* Name.Namespace */
# .ca-7ecf6037 .nx { color: #E6EDF3 } /* Name.Other */
# .ca-7ecf6037 .py { color: #79C0FF } /* Name.Property */
# .ca-7ecf6037 .nt { color: #7EE787 } /* Name.Tag */
# .ca-7ecf6037 .nv { color: #79C0FF } /* Name.Variable */
# .ca-7ecf6037 .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .ca-7ecf6037 .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .ca-7ecf6037 .w { color: #6E7681 } /* Text.Whitespace */
# .ca-7ecf6037 .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .ca-7ecf6037 .mf { color: #A5D6FF } /* Literal.Number.Float */
# .ca-7ecf6037 .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .ca-7ecf6037 .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .ca-7ecf6037 .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .ca-7ecf6037 .sa { color: #79C0FF } /* Literal.String.Affix */
# .ca-7ecf6037 .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .ca-7ecf6037 .sc { color: #A5D6FF } /* Literal.String.Char */
# .ca-7ecf6037 .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .ca-7ecf6037 .sd { color: #A5D6FF } /* Literal.String.Doc */
# .ca-7ecf6037 .s2 { color: #A5D6FF } /* Literal.String.Double */
# .ca-7ecf6037 .se { color: #79C0FF } /* Literal.String.Escape */
# .ca-7ecf6037 .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .ca-7ecf6037 .si { color: #A5D6FF } /* Literal.String.Interpol */
# .ca-7ecf6037 .sx { color: #A5D6FF } /* Literal.String.Other */
# .ca-7ecf6037 .sr { color: #79C0FF } /* Literal.String.Regex */
# .ca-7ecf6037 .s1 { color: #A5D6FF } /* Literal.String.Single */
# .ca-7ecf6037 .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .ca-7ecf6037 .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .ca-7ecf6037 .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .ca-7ecf6037 .vc { color: #79C0FF } /* Name.Variable.Class */
# .ca-7ecf6037 .vg { color: #79C0FF } /* Name.Variable.Global */
# .ca-7ecf6037 .vi { color: #79C0FF } /* Name.Variable.Instance */
# .ca-7ecf6037 .vm { color: #79C0FF } /* Name.Variable.Magic */
# .ca-7ecf6037 .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .ca-7ecf6037{background:#0d1117!important;color:#e6edf3!important;font-size:14px}
# .ca-7ecf6037 pre{margin:0;padding:0;line-height:1.5em!important;background:#0d1117!important;color:#e6edf3!important}
# .ca-7ecf6037 code{background:#0d1117!important;color:#e6edf3!important}
# .ca-7ecf6037 .hll{background:#3d4626!important;display:block;width:100%}
# .ca-7ecf6037 .linenos{background:#0d1117!important;color:#e6edf3!important}
# </style>
# <div style="display:inline-flex;align-items:flex-start;background:#0d1117;border-radius:8px;border:1px solid #444;margin:10px 0;font-family:monospace;font-size:14px;line-height:1.5em">
# <div style="flex:3;overflow-x:auto;background:#0d1117"><div class="ca-7ecf6037"><pre><span class="linenos"> 1</span><span class="k">def</span><span class="w"> </span><span class="nf">_execute_action</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">response</span><span class="p">:</span> <span class="n">Response</span><span class="p">)</span> <span class="o">-&gt;</span> <span class="kc">None</span><span class="p">:</span>
# <span class="linenos"> 2</span><span class="w">    </span><span class="sd">"""Execute a tool action."""</span>
# <span class="linenos"> 3</span>
# <span class="linenos"> 4</span>    <span class="c1"># ACTION: execute tools</span>
# <span class="hll"><span class="linenos"> 5</span>    <span class="n">result</span> <span class="o">=</span> <span class="bp">self</span><span class="o">.</span><span class="n">tools</span><span class="o">.</span><span class="n">execute</span><span class="p">(</span><span class="n">response</span><span class="p">)</span>
# </span><span class="linenos"> 6</span>
# <span class="linenos"> 7</span>    <span class="c1"># OBSERVATION: add tool results to memory and display</span>
# <span class="hll"><span class="linenos"> 8</span>    <span class="n">role</span><span class="p">,</span> <span class="n">observation</span> <span class="o">=</span> <span class="bp">self</span><span class="o">.</span><span class="n">tools</span><span class="o">.</span><span class="n">observation</span><span class="p">(</span><span class="n">result</span><span class="p">)</span>
# </span><span class="hll"><span class="linenos"> 9</span>    <span class="bp">self</span><span class="o">.<

# %% [markdown]
# We can also show it all the changes at once. Compared to previous chapters, the difference is a bit bigger as a result of the `for` loop:

# %%
from illustrated_agents.chapters.ch6 import tinyagents_diff; tinyagents_diff
# Out:
# <style>
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .dv-3f114481 .hll { background-color: #6e7681 }
# .dv-3f114481 { background: #0d1117; color: #E6EDF3 }
# .dv-3f114481 .c { color: #8B949E; font-style: italic } /* Comment */
# .dv-3f114481 .err { color: #F85149 } /* Error */
# .dv-3f114481 .esc { color: #E6EDF3 } /* Escape */
# .dv-3f114481 .g { color: #E6EDF3 } /* Generic */
# .dv-3f114481 .k { color: #FF7B72 } /* Keyword */
# .dv-3f114481 .l { color: #A5D6FF } /* Literal */
# .dv-3f114481 .n { color: #E6EDF3 } /* Name */
# .dv-3f114481 .o { color: #FF7B72; font-weight: bold } /* Operator */
# .dv-3f114481 .x { color: #E6EDF3 } /* Other */
# .dv-3f114481 .p { color: #E6EDF3 } /* Punctuation */
# .dv-3f114481 .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .dv-3f114481 .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .dv-3f114481 .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .dv-3f114481 .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .dv-3f114481 .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .dv-3f114481 .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .dv-3f114481 .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .dv-3f114481 .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .dv-3f114481 .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .dv-3f114481 .gr { color: #FFA198 } /* Generic.Error */
# .dv-3f114481 .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .dv-3f114481 .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .dv-3f114481 .go { color: #8B949E } /* Generic.Output */
# .dv-3f114481 .gp { color: #8B949E } /* Generic.Prompt */
# .dv-3f114481 .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .dv-3f114481 .gu { color: #79C0FF } /* Generic.Subheading */
# .dv-3f114481 .gt { color: #FF7B72 } /* Generic.Traceback */
# .dv-3f114481 .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .dv-3f114481 .kc { color: #79C0FF } /* Keyword.Constant */
# .dv-3f114481 .kd { color: #FF7B72 } /* Keyword.Declaration */
# .dv-3f114481 .kn { color: #FF7B72 } /* Keyword.Namespace */
# .dv-3f114481 .kp { color: #79C0FF } /* Keyword.Pseudo */
# .dv-3f114481 .kr { color: #FF7B72 } /* Keyword.Reserved */
# .dv-3f114481 .kt { color: #FF7B72 } /* Keyword.Type */
# .dv-3f114481 .ld { color: #79C0FF } /* Literal.Date */
# .dv-3f114481 .m { color: #A5D6FF } /* Literal.Number */
# .dv-3f114481 .s { color: #A5D6FF } /* Literal.String */
# .dv-3f114481 .na { color: #E6EDF3 } /* Name.Attribute */
# .dv-3f114481 .nb { color: #E6EDF3 } /* Name.Builtin */
# .dv-3f114481 .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .dv-3f114481 .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .dv-3f114481 .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .dv-3f114481 .ni { color: #FFA657 } /* Name.Entity */
# .dv-3f114481 .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .dv-3f114481 .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .dv-3f114481 .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .dv-3f114481 .nn { color: #FF7B72 } /* Name.Namespace */
# .dv-3f114481 .nx { color: #E6EDF3 } /* Name.Other */
# .dv-3f114481 .py { color: #79C0FF } /* Name.Property */
# .dv-3f114481 .nt { color: #7EE787 } /* Name.Tag */
# .dv-3f114481 .nv { color: #79C0FF } /* Name.Variable */
# .dv-3f114481 .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .dv-3f114481 .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .dv-3f114481 .w { color: #6E7681 } /* Text.Whitespace */
# .dv-3f114481 .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .dv-3f114481 .mf { color: #A5D6FF } /* Literal.Number.Float */
# .dv-3f114481 .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .dv-3f114481 .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .dv-3f114481 .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .dv-3f114481 .sa { color: #79C0FF } /* Literal.String.Affix */
# .dv-3f114481 .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .dv-3f114481 .sc { color: #A5D6FF } /* Literal.String.Char */
# .dv-3f114481 .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .dv-3f114481 .sd { color: #A5D6FF } /* Literal.String.Doc */
# .dv-3f114481 .s2 { color: #A5D6FF } /* Literal.String.Double */
# .dv-3f114481 .se { color: #79C0FF } /* Literal.String.Escape */
# .dv-3f114481 .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .dv-3f114481 .si { color: #A5D6FF } /* Literal.String.Interpol */
# .dv-3f114481 .sx { color: #A5D6FF } /* Literal.String.Other */
# .dv-3f114481 .sr { color: #79C0FF } /* Literal.String.Regex */
# .dv-3f114481 .s1 { color: #A5D6FF } /* Literal.String.Single */
# .dv-3f114481 .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .dv-3f114481 .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .dv-3f114481 .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .dv-3f114481 .vc { color: #79C0FF } /* Name.Variable.Class */
# .dv-3f114481 .vg { color: #79C0FF } /* Name.Variable.Global */
# .dv-3f114481 .vi { color: #79C0FF } /* Name.Variable.Instance */
# .dv-3f114481 .vm { color: #79C0FF } /* Name.Variable.Magic */
# .dv-3f114481 .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .dv-3f114481{background:#0d1117!important;color:#e6edf3!important;font-size:14px;line-height:1.4;border-radius:8px;padding:12px;overflow-x:auto}
# .dv-3f114481 pre{background:#0d1117!important;color:#e6edf3!important;margin:0}
# .dv-3f114481 code{background:#0d1117!important;color:#e6edf3!important}
# </style>
# <div class="dv-3f114481"><pre><span></span><span class="gd">--- ch5.TinyAgent</span>
# <span class="gi">+++ ch6.TinyAgent</span>
# <span class="gu">@@ -1,16 +1,17 @@</span>
# <span class="w"> </span>class TinyAgent:
# <span class="w"> </span>    """A minimal, modular, and educational agent framework."""
# <span class="w"> </span>
# <span class="gd">-    def __init__(self, llm: LLM, memory: Memory, tools: Tools):</span>
# <span class="gi">+    def __init__(self, llm: LLM, memory: Memory, tools: Tools, planner: ReAct):</span>
# <span class="w"> </span>        self.llm = llm
# <span class="w"> </span>        self.memory = memory
# <span class="w"> </span>        self.tools = tools
# <span class="gd">-        self.planner = None  # Chapter 6: Add Planning</span>
# <span class="gi">+        self.planner = planner</span>
# <span class="w"> </span>
# <span class="w"> </span>        self.trajectory = Trajectory()
# <span class="w"> </span>
# <span class="w"> </span>        # Build system prompt with all components
# <span class="w"> </span>        system_prompt = "You are a helpful assistant.\n\n"
# <span class="gi">+        system_prompt += self.planner.prompt</span>
# <span class="w"> </span>        system_prompt += self.tools.prompt
# <span class="w"> </span>        self.memory.add("system", system_prompt)
# <span class="w"> </span>
# <span class="gu">@@ -19,9 +20,15 @@</span>
# <span class="w"> </span>        self.memory.add("user", task)
# <span class="w"> </span>        self.trajectory.initialize(task)
# <span class="w"> </span>
# <span class="gd">-        return self._step()</span>
# <span class="gi">+        # *Autonomy* loop</span>
# <span class="gi">+        for step in range(self.planner.max_steps):</span>
# <span class="gi">+            result = self._step()</span>
# <span class="gi">+            if result is not None:</span>
# <span class="gi">+                return result</span>
# <span class="w"> </span>
# <span class="gd">-    def _step(self) -&gt; str:</span>
# <span class="gi">+        return "Max steps reached without complet

# %% [markdown]
# Now that we went through all steps, let's start creating your ReAct-based `TinyAgent` and explore whether it can actually do things autonomously!

# %% [markdown]
# ## 6 - Running The Autonomous `TinyAgent`

# %%
from illustrated_agents.toolbox import add, multiply, subtract

# Register tools
tools = Tools()
tools.add_tool("add", add, "add(a: str, b: str)")
tools.add_tool("subtract", subtract, "subtract(a: str, b: str)")
tools.add_tool("multiply", multiply, "multiply(a: str, b: str)")

# Memory
memory = Memory()

# ReAct
react = ReAct(max_steps=10)

# Create agent
agent = TinyAgent(llm=llm, tools=tools, memory=memory, planner=react)

# Multi-step task with reasoning
agent.run("What is (4.6 + 6.685) x 4, and then subtract 3.14 from the result?")
# Out:
# '42.0'

# %% [markdown]
# Amazing! If you used **Gemma 3 12B** then it should have run correctly. It performed all tasks in sequence and gave us back the final reply. Let's explore how many steps it took:

# %%
from illustrated_agents.utils import TrajectoryViewer
TrajectoryViewer(agent.trajectory)
# Out:
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .highlight .hll { background-color: #ffffcc }
# .highlight { background: #f8f8f8; }
# .highlight .c { color: #3D7B7B; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #F00 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666 } /* Operator */
# .highlight .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #9C6500 } /* Comment.Preproc */
# .highlight .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .highlight .gr { color: #E40000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #008400 } /* Generic.Inserted */
# .highlight .go { color: #717171 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #04D } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #687822 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #00F; font-weight: bold } /* Name.Class */
# .highlight .no { color: #800 } /* Name.Constant */
# .highlight .nd { color: #A2F } /* Name.Decorator */
# .highlight .ni { color: #717171; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #00F } /* Name.Function */
# .highlight .nl { color: #767600 } /* Name.Label */
# .highlight .nn { color: #00F; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #A2F; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #BBB } /* Text.Whitespace */
# .highlight .mb { color: #666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666 } /* Literal.Number.Float */
# .highlight .mh { color: #666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #A45A77 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #00F } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666 } /* Literal.Number.Integer.Long */
#     .trajectory details { margin: 6px 0; border: 1px solid #e4e4e7; border-radius: 6px; }
#     .trajectory summary { cursor: pointer; padding: 8px 12px; font-weight: 500; background: #fafafa; }
#     .trajectory summary .kind { color: #71717a; font-weight: 400; margin-left: 6px; }
#     .trajectory .run > summary { background: #eef2ff; }
#     .trajectory .steps { margin-left: 20px; }
#     .trajectory .field { padding: 8px 12px; }
#     .trajectory .label { color: #52525b; font-size: 0.8em; font-weight: 700; text-transform: uppercase; letter-spacing: 0.06em; margin-bottom: 4px; }
#     .trajectory pre { margin: 0; white-space: pre-wrap; font-family: ui-monospace, monospace; font-size: 0.9em; }
#     .trajectory .highlight { background: transparent; font-size: 0.9em; }
#     </style><div class='trajectory'><details class='run'><summary>Run 1 <span class='kind'>· User query</span></summary><div class='field'><pre>What is (4.6 + 6.685) x 4, and then subtract 3.14 from the result?</pre></div></details><div class='steps'><details><summary>Step 1 <span class='kind'>· action</span></summary><div class='field'><div class='label'>thought</div><pre>First, I need to add 4.6 and 6.685. Then I need to multiply the sum by 4. Finally, I need to subtract 3.14 from the result.</pre></div>
# <div class='field'><div class='label'>action</div><div class='highlight'><span class="p">{</span>
# <span class="w">  </span><span class="nt">"tool"</span><span class="p">:</span><span class="w"> </span><span class="s2">"add"</span><span class="p">,</span>
# <span class="w">  </span><span class="nt">"kwargs"</span><span class="p">:</span><span class="w"> </span><span class="p">{</span>
# <span class="w">    </span><span class="nt">"a"</span><span class="p">:</span><span class="w"> </span><span class="s2">"4.6"</span><span class="p">,</span>
# <span class="w">    </span><span class="nt">"b"</span><span class="p">:</span><span class="w"> </span><span class="s2">"6.685"</span>
# <span class="w">  </span><span class="p">}</span>
# <span class="p">}</span>
# </div></div>
# <div class='field'><div class='label'>observation</div><pre>OBSERVATION: 11.285</pre></div></details>
# <details><summary>Step 2 <span class='kind'>· action</span></summary><div class='field'><div class='label'>thought</div><pre>Now I need to multiply 11.285 by 4.</pre></div>
# <div class='field'><div class='label'>action</div><div class='highlight'><span class="p">{</span>
# <span class="w">  </span><span class="nt">"tool"</span><span class="p">:</span><span class="w"> </span><span class="s2">"multiply"</span><span class="p">,</span>
# <span class="w">  </span><span class="nt">"kwargs"</span><span class="p">:</span><span class="w"> </span><span class="p">{</span>
# <span class="w">    </span><span class="nt">"a"</span><span class="p">:</span><span class="w"> </span><span class="s2">"11.285"</span><span class="p">,</span>
# <span class="w">    </span><span class="nt">"b"</span><span class="p">:</span><span class="w"> </span><span class="s2">"4"</span>
# <span class="w">  </span><span class="p">}</span>
# <span class="p">}</span>
# </div></div>
# <div class='field'><div class='label'>observation</div><pre>OB

# %%
from rich import print

print(agent.trajectory.runs)
# Out:
# [
#     {
#         'query': 'What is (4.6 + 6.685) x 4, and then subtract 3.14 from the result?',
#         'steps': [
#             Step(
#                 thought='First, I need to add 4.6 and 6.685. Then I need to multiply the sum by 4. Finally, I need
# to subtract 3.14 from the result.',
#                 action={'tool': 'add', 'kwargs': {'a': '4.6', 'b': '6.685'}},
#                 observation='OBSERVATION: 11.285',
#                 answer=None,
#                 metadata=None
#             ),
#             Step(
#                 thought='Now I need to multiply 11.285 by 4.',
#                 action={'tool': 'multiply', 'kwargs': {'a': '11.285', 'b': '4'}},
#                 observation='OBSERVATION: 45.14',
#                 answer=None,
#                 metadata=None
#             ),
#             Step(
#                 thought='Now I need to subtract 3.14 from 45.14.',
#                 action={'tool': 'subtract', 'kwargs': {'a': '45.14', 'b': '3.14'}},
#                 observation='OBSERVATION: 42.0',
#                 answer=None,
#                 metadata=None
#             ),
#             Step(
#                 thought='I have completed all the steps. Now I can provide the final answer.',
#                 action=None,
#                 observation=None,
#                 answer='42.0',
#                 metadata=None
#             )
#         ]
#     }
# ]

# %% [markdown]
# In our example, 3 tools were called in sequence. Then, your `TinyAgent` created a final message with the result. As always, let's end with exploring the Agent's memory:

# %%
from rich import print
print(agent.memory.messages)
# Out:
# [
#     {
#         'role': 'system',
#         'content': 'You are a helpful assistant.\n\n\n# ReAct (Reason and Act)\n\nYou are a ReAct agent that
# performs exactly ONE step per turn.\n\n## ReAct Format\n\nYou use the following format for each step:\n\nTHOUGHT:
# [Your reasoning about what to do next]\nACTION:\n{\n    "tool": "a_tool_name",\n    "kwargs": {"param":
# "value"},\n}\n\nAn observation will be provided after each action. You do not generate the observation
# yourself.\n\n## ReAct Completion\n\nTo provide the final answer to the task, use an action blob with "tool":
# "final_answer" tool. \nIt is the only way to complete the task, else you will be stuck on a loop. \nSo your final
# output should look like this:\n\nACTION:\n{\n    "tool": "final_answer",\n    "kwargs": "insert your final answer
# here"\n}\n\nUse the `final_answer` tool when you are completely done with all subtasks and have the final answer
# ready.\nYou can also use `final_answer` to directly reply to a user\'s question without using any other
# tools.\n\n\n# Tools\n\nIf needed, you can only use the following tools to assist you in completing tasks:\n\n`add`:
# add(a: str, b: str)\n`subtract`: subtract(a: str, b: str)\n`multiply`: multiply(a: str, b: str)\n\nTo use a tool,
# respond with JSON: {"tool": "name", "kwargs": {"param": "value"}}\n'
#     },
#     {'role': 'user', 'content': 'What is (4.6 + 6.685) x 4, and then subtract 3.14 from the result?'},
#     {
#         'role': 'assistant',
#         'content': 'THOUGHT: First, I need to add 4.6 and 6.685. Then I need to multiply the sum by 4. Finally, I
# need to subtract 3.14 from the result.\nACTION:\n{\n    "tool": "add",\n    "kwargs": {"a": "4.6", "b":
# "6.685"}\n}\n'
#     },
#     {'role': 'user', 'content': 'OBSERVATION: 11.285'},
#     {
#         'role': 'assistant',
#         'content': 'THOUGHT: Now I need to multiply 11.285 by 4.\nACTION:\n{\n    "tool": "multiply",\n
# "kwargs": {"a": "11.285", "b": "4"}\n}'
#     },
#     {'role': 'user', 'content': 'OBSERVATION: 45.14'},
#     {
#         'role': 'assistant',
#         'content': 'THOUGHT: Now I need to subtract 3.14 from 45.14.\nACTION:\n{\n    "tool": "subtract",\n
# "kwargs": {"a": "45.14", "b": "3.14"}\n}'
#     },
#     {'role': 'user', 'content': 'OBSERVATION: 42.0'},
#     {
#         'role': 'assistant',
#         'content': 'THOUGHT: I have completed all the steps. Now I can provide the final answer.\nACTION:\n{\n
# "tool": "final_answer",\n    "kwargs": "42.0"\n}'
#     }
# ]

# %% [markdown]
# <hr style="height: 5px; border: none; border-radius: 5px; background: linear-gradient(to right, #000000, #7D7D7D);" />

# %% [markdown]
# # What We Built
#
# In this chapter, we covered what makes your `TinyAgent` autonomous... a for-loop! This for-loop, driven by the Reason and Act (ReAct) framework is quite capable. As we covered in the book, ReAct is not something we always will do explicitly because newer models tend to be trained on that already. Going through the steps of it helps you understand what the LLM is doing under the hood that makes this all possible.

# %%
from illustrated_agents.chapters.ch6 import what_we_built; what_we_built
# Out:
# ╭───────────────────────────────────────────────── What We Built ─────────────────────────────────────────────────╮
# │ TinyAgent                                                                                                       │
# │ ├── agent.py      ← Updated (Autonomy with a for-loop and ReAct planner.)                                       │
# │ ├── llm.py                                                                                                      │
# │ ├── memory.py                                                                                                   │
# │ ├── planning.py   ← New (Added the ReAct (Reason and Act) framework)                                            │
# │ ├── toolbox.py                                                                                                  │
# │ ├── tools.py                                                                                                    │
# │ └── trajectory.py                                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# # What's Next
#
# Next up is `chapter06_native_react.ipynb` which covers how to do this ReAct loop but with native tool calling and reasoning capabilities instead.
